# %% [markdown]
# ### INTRODUCTION ###
#
# This notebook outlines the process taken to produce relative bias (RB), or uncertainty,  measurements for the ICARUS detector from Coulomb repulsion effects using results from the DarkSide project in Agnes, P., et al. "Electroluminescence pulse shape and electron diffusion in liquid argon measured in a dual-phase TPC." Nuclear Instruments and Methods in Physics Research Section A: Accelerators, Spectrometers, Detectors and Associated Equipment 904 (2018): 23-34. https://arxiv.org/abs/1802.01427.
#
# The data used is digitized from Figure 15 (a) in the above paper for 140 keV electron recoil events in a 200 V/cm drift field and a 2.8 kV/cm extraction field.
#
# The analysis begins with importing numpy, several matplot features, and lmfit's Model tool for data fitting with constraints.

# %%
##########################################
# IMPORTS FOR ANALYSIS AND VISUALIZATION #
##########################################

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.cm as cm
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

### LIBRARY FOR FITTING TO DATA WITH CONSTRAINTS ###
from lmfit import Model

# %% [markdown]
# ### VARIABLES ###
#
# - The cleaning_val variables refer to the highest value in the x axis, which all three data     sets share, that data for the analysis will be included to remove outliers
# - The lower_curve_cleaning variables denote a range of values, between the values of the two     variables, on the x axis of the 150 V/cm data set that are also cleaned
# - t_A and t_C are ICARUS specific values for the drift times to reach the anode and cathode in   the detector
# - num_of_points_... refers to the number of intermediate points used in the RB calculation       excluding t_C but including t_A and limited by ensuring different wires are sampled by each   intermediate point
# - The last set of variables define the constants used in the charge density calculations

# %%
##############################################
# VARUABLES USED THROUGHOUT ANALYSIS PROCESS #
##############################################

### VARIABLE FOR RB ANALYSIS ###
cleaning_val_100_V_per_cm = 510
cleaning_val_150_V_per_cm = 460
cleaning_val_200_V_per_cm = 377

lower_curve_cleaning_150_V_per_cm_lower_bound = 6
lower_curve_cleaning_150_V_per_cm_upper_bound = 13

t_A = 92.3
t_C = 851.1 

### CHANGE TO PERSONAL DIRECTORY FOR DATA ###
data_list = ["/home/sebastian/Downloads/Variance_vs_drift_time_100_V_per_cm.csv", 
            "/home/sebastian/Downloads/Variance_vs_drift_time_150_V_per_cm.csv", 
            "/home/sebastian/Downloads/Variance_vs_drift_time_200_V_per_cm.csv"]

num_of_points_excluding_t_C_in_RB_calc = 6

### VARIABLES FOR CHAGRE DENSITY CALCULATION ###
LAr_density = 1.3954
LAr_ionization_energy = 23.6
DarkSide_reco_factor = 0.319723
DarkSide_stopping_power = 2.41*(10**6)
ICARUS_reco_factor = 0.703
ICARUS_stopping_power = 1.5*(10**6)

# %% [markdown]
# ### FUNCTIONS ###
#
#
#
# This notebook uses the following in its analysis:
# - A cleaning function to exclude data above an amount specified in the variables
# - A function that fits the remainined data with a power law plus linear function:    $y=A(x+B)^C+D(x+B)$
# - A function to calculate the residuals of each fit
# - Three functions used in the relative bias calculation: y_func, const_linear_fit, and w_func
# - A function for calculating the relative bias as t_A changes over a range of values from 92.3   µs to 136.3 µs to ensure sampling from different wires

# %%
#############
# FUNCTIONS #
#############

### DATA CLEANING FUNCTION ###
def cleaning_func(input_data):
    data = np.loadtxt(input_data)
    x_axis = data[:,0]
    y_axis = data[:,1]
    x_data_list = []
    y_data_list = []
    if input_data == data_list[0]:
        for i in np.arange(len(x_axis)):
            if x_axis[i] <= cleaning_val_100_V_per_cm: 
                x_data_list.append(x_axis[i])
                y_data_list.append(y_axis[i])
    if input_data == data_list[1]:
        for i in np.arange(len(x_axis)):
            if x_axis[i] <= cleaning_val_150_V_per_cm:
                x_data_list.append(x_axis[i])
                y_data_list.append(y_axis[i])
        delete = []
        for i in np.arange(lower_curve_cleaning_150_V_per_cm_lower_bound, lower_curve_cleaning_150_V_per_cm_upper_bound):
            delete.append(i)
        x_data_list = np.delete(x_data_list, delete, 0)
        y_data_list = np.delete(y_data_list, delete, 0)
    if input_data == data_list[2]:
        for i in np.arange(len(x_axis)):
            if x_axis[i] <= cleaning_val_200_V_per_cm: 
                x_data_list.append(x_axis[i])
                y_data_list.append(y_axis[i])
    x_data = np.array(x_data_list)
    y_data = np.array(y_data_list)
    combined_data_list = [x_data, y_data]
    return combined_data_list

### FITTING FUNCTION USED IN RELATIVE BIAS CALCULATION ###
def data_fitting(x, y):
    def data_fit(t, A, B, C, D):
        return A*(t+B)**(C)+D*(t+B)
    mymodel = Model(data_fit)
    params = mymodel.make_params(A=-0.1, B=0.1, C=-0.1, D=0.1)  
    params['A'].max = 0
    params['C'].max = 0 
    result = mymodel.fit(y, params, t=x)
    print(result.fit_report())
    val1 = result.params['A'].value
    val2 = result.params['B'].value
    val3 = result.params['C'].value
    val4 = result.params['D'].value
    params_list = [val1, val2, val3, val4]
    return params_list

### FINDING RESIDUALS FOR DATA TO DETERMINE FIT QUALITY ###
def residuals_func(input_data_x, input_data_y, a, b, c, d):
    residuals = []
    y_data_fit_len_data = []
    for item in input_data_x:
        y_data_fit_len_data.append(a*(item+b)**(c)+d*(item+b))
    for i in np.arange(len(y_data_fit_len_data)):
        residuals.append(input_data_y[i]-y_data_fit_len_data[i])
    return residuals

### LINEAR PORTION OF FIT AS FUNCTION TO BE USED IN RB CALCULATION ###
def y_func(t, b, d):
    line_result = d*(t+b)
    return line_result
 
### LINEAR FUNCTION WITH NO Y-INT USED IN w_func CALCULATION ###
def const_linear_fit(t, n):
    return n*t

### FUNCTION USED TO FIND LINEAR FUCTION FIT TO 7 POINTS IN ###
### GLOBAL FIT DATA INCLUDING THE t_A AND t_C POINTS ###
def w_func(t, input_time, a, b, c, d):
    var_t_C = a*(t_C+b)**(c)+d*(t_C+b)
    var_t_A = a*(t+b)**(c)+d*(t+b)
    diff = t_C-t 
    delta_t = diff/num_of_points_excluding_t_C_in_RB_calc
    point_1 = t+delta_t
    point_2 = point_1+delta_t
    point_3 = point_2+delta_t
    point_4 = point_3+delta_t
    point_5 = point_4+delta_t
    var_point_1 = a*(point_1+b)**(c)+d*(point_1+b)
    var_point_2 = a*(point_2+b)**(c)+d*(point_2+b)
    var_point_3 = a*(point_3+b)**(c)+d*(point_3+b)
    var_point_4 = a*(point_4+b)**(c)+d*(point_4+b)
    var_point_5 = a*(point_5+b)**(c)+d*(point_5+b)
    RB_data = [var_t_A, var_point_1, var_point_2, var_point_3, var_point_4, var_point_5, var_t_C]
#     RB_data_shifted = [var_t_A-var_t_C, var_point_1-var_t_C, var_point_2-var_t_C, var_point_3-var_t_C, var_point_4-var_t_C, var_point_5-var_t_C, var_t_C-var_t_C]
    t_data = [t, point_1, point_2, point_3, point_4, point_5, t_C]
#     t_data_shifted = [t-t_C, point_1-t_C, point_2-t_C, point_3-t_C, point_4-t_C, point_5-t_C, t_C-t_C]
    
    mymodel = Model(const_linear_fit)
#     params = mymodel.make_params(n=1) 
    params = mymodel.make_params(n=1, m=1) 
    
#     fit_t_A = mymodel.fit([var_t_A, var_t_C], params, t=[t, t_C])
#     fit_point_1 = mymodel.fit([var_point_1, var_t_C], params, t=[point_1, t_C])
#     fit_point_2 = mymodel.fit([var_point_2, var_t_C], params, t=[point_2, t_C])
#     fit_point_3 = mymodel.fit([var_point_3, var_t_C], params, t=[point_3, t_C])
#     fit_point_4 = mymodel.fit([var_point_4, var_t_C], params, t=[point_4, t_C])
#     fit_point_5 = mymodel.fit([var_point_5, var_t_C], params, t=[point_5, t_C])
    
    fit_t_A = mymodel.fit([var_t_A-var_t_C, var_t_C-var_t_C], params, t=[t-t_C, t_C-t_C])
    fit_point_1 = mymodel.fit([var_point_1-var_t_C, var_t_C-var_t_C], params, t=[point_1-t_C, t_C-t_C])
    fit_point_2 = mymodel.fit([var_point_2-var_t_C, var_t_C-var_t_C], params, t=[point_2-t_C, t_C-t_C])
    fit_point_3 = mymodel.fit([var_point_3-var_t_C, var_t_C-var_t_C], params, t=[point_3-t_C, t_C-t_C])
    fit_point_4 = mymodel.fit([var_point_4-var_t_C, var_t_C-var_t_C], params, t=[point_4-t_C, t_C-t_C])
    fit_point_5 = mymodel.fit([var_point_5-var_t_C, var_t_C-var_t_C], params, t=[point_5-t_C, t_C-t_C])
    
    slope_t_A = fit_t_A.params['n'].value
    slope_point_1 = fit_point_1.params['n'].value
    slope_point_2 = fit_point_2.params['n'].value
    slope_point_3 = fit_point_3.params['n'].value
    slope_point_4 = fit_point_4.params['n'].value
    slope_point_5 = fit_point_5.params['n'].value
    
#     yint_t_A = fit_t_A.params['m'].value
#     yint_point_1 = fit_point_1.params['m'].value
#     yint_point_2 = fit_point_2.params['m'].value
#     yint_point_3 = fit_point_3.params['m'].value
#     yint_point_4 = fit_point_4.params['m'].value
#     yint_point_5 = fit_point_5.params['m'].value
    
    slope_list = [slope_t_A, slope_point_1, slope_point_2, slope_point_3, slope_point_4, slope_point_5]
    
#     yint_t_A = var_t_C-(slope_t_A)*(t_C)
#     yint_point_1 = var_t_C-(slope_point_1)*(t_C)
#     yint_point_2 = var_t_C-(slope_point_2)*(t_C)
#     yint_point_3 = var_t_C-(slope_point_3)*(t_C)
#     yint_point_4 = var_t_C-(slope_point_4)*(t_C)
#     yint_point_5 = var_t_C-(slope_point_5)*(t_C)
    
#     yint_list = [yint_t_A, yint_point_1, yint_point_2, yint_point_3, yint_point_4, yint_point_5]
    
    avg_slope_sum = 0
#     avg_yint_sum = 0
    for i in np.arange(len(slope_list)):
        avg_slope_sum = slope_list[i] + avg_slope_sum
#         avg_yint_sum = yint_list[i] + avg_yint_sum
    avg_slope = avg_slope_sum/len(slope_list)
#     avg_yint = avg_yint_sum/len(yint_list)
    
    avg_yint = var_t_C-(avg_slope)*(t_C)
    w_func_output = avg_slope*(input_time)+avg_yint
    
    
    x = []
    y_global = []
    constrained_fit_data = []
    nonconstrained_fit_data = []
    n, m = np.polyfit(t_data, RB_data, 1)
    if input_time == 92.3:
        for i in np.arange(0, t_C+100):
            x.append(i)
            y_global.append(a*(i+b)**(c)+d*(i+b))
            constrained_fit_data.append(avg_slope*(i)+avg_yint)
            nonconstrained_fit_data.append(n*i+m)
        fig, ax = plt.subplots(1)
        ax.plot(x, y_global, color='blue',  label='Global fit function')
        ax.plot(x, constrained_fit_data, color='red', label='Fit through t_C')
        
        ### OPTION TO PLOT FIT THAT DOESN'T GO THROUGH t_C POINT ###
#         ax.plot(x, nonconstrained_fit_data, label='Fit not constrained through t_C')
        ax.scatter(t, var_t_A, color='black', label='t_A')
        ax.scatter(point_1, var_point_1, color='lightgreen')
        ax.scatter(point_2, var_point_2, color='lightgreen')
        ax.scatter(point_3, var_point_3, color='lightgreen')
        ax.scatter(point_4, var_point_4, color='lightgreen')
        ax.scatter(point_5, var_point_5, color='lightgreen')
        ax.scatter(t_C, var_t_C, color='orange', label='t_C')
        ax.set_xlim(0, 1000)
        ax.set_xlabel('Drift time (μs)')
        ax.set_ylabel('Variance (µs$^2$)')
        ax.legend()
#         ax.set_title('Fit comparison for 100 V/cm data')
#         fig.savefig('Data_comparison_100.pdf')
        print('Variance at t_C:', var_t_C)
        print('Value of linear fit at t_C:', avg_slope*(t_C)+avg_yint)

        ### CHECKING TO MAKE SURE LINEAR FIT GOES THROUGH t_C POINT ###
#         print('Global fit result at t_C:', var_t_C)
#         print('Linear fit result at t_C:', val_1*(t_C)+yint)
    return w_func_output

### RB CALCULATION AS A FUNCTION OF t_A ###
def RB_per_t_A(t):
    RB_fit = []
    V_per_cm_100_RB = []
    V_per_cm_150_RB = []
    V_per_cm_200_RB = []
    
    ### PULLING DATA FOR 100, 150, AND 200 V/CM ###
    for item in data_list:
        data = cleaning_func(item)
        x_data = np.array(data[0])
        y_data = np.array(data[1])
        
        ### DOING POWER LAW PLUS LINEAR FUNCTION FIT ###
        data_fit_params = data_fitting(x_data, y_data)
        t_A_list = []
        
        ### DOING RELATIVE BIAS CALCULATIONS FOR A RANGE OF t_A VALUES KEEPING t_C CONSTANT ###
        ### USING FIT PARAMETERS FOR CALCULATIONS ###
        for i in np.arange(t_A, t, 0.1):
            RB_result = 100*(((w_func(i, t_C, data_fit_params[0], data_fit_params[1], data_fit_params[2], data_fit_params[3])-
                               w_func(i, i, data_fit_params[0], data_fit_params[1], data_fit_params[2], data_fit_params[3]))
                              -(y_func(t_C, data_fit_params[1], data_fit_params[3])
                                -y_func(i, data_fit_params[1], data_fit_params[3])))
                             /(y_func(t_C, data_fit_params[1], data_fit_params[3])-
                               y_func(i, data_fit_params[1], data_fit_params[3])))
            t_A_list.append(i)

            ### STORING CALCLATION RESULTS FOR EACH DATA SET SEPERATELY ###
            if item == data_list[0]:
                V_per_cm_100_RB.append(RB_result)
            if item == data_list[1]:
                V_per_cm_150_RB.append(RB_result)
            if item == data_list[2]:
                V_per_cm_200_RB.append(RB_result)
                
    ### PLOTTING AND PRINTING RESULTS ###
    print('100 V/cm bias:', V_per_cm_100_RB[0])
    print('150 V/cm bias:', V_per_cm_150_RB[0])
    print('200 V/cm bias:', V_per_cm_200_RB[0])
    fig, ax = plt.subplots(1)
    plt.plot(t_A_list, V_per_cm_100_RB, color='blue', label='100 V/cm bias')
    plt.plot(t_A_list, V_per_cm_150_RB, color='darkgreen', label='150 V/cm bias')
    plt.plot(t_A_list, V_per_cm_200_RB, color='red', label='200 V/cm bias')
    plt.xlabel('t_A (μs)')
    plt.ylabel('Relative bias (%)')
    plt.title('Relative bias as a function of t_A')
    plt.legend()
#     plt.savefig('Relative_bias_vs_t_A.pdf')

# %% [markdown]
# ### CHARGE DENSITIES ###
#
# The first section of this analysis looks to compare the charge density for the electrons in the DarkSide experiment to the MIPs (muons) in ICARUS.

# %%
################################################################################
# dQ/dx CALCULATION FOR 140 keV ELECTRON RECOIL EVENTS IN 200 V/cm DRIFT FIELD #
################################################################################

dQdx_DarkSide = (DarkSide_reco_factor)/(LAr_ionization_energy)*(LAr_density)*(DarkSide_stopping_power)/(10)
dQdx_ICARUS = (ICARUS_reco_factor)/(LAr_ionization_energy)*(LAr_density)*(ICARUS_stopping_power)/10

print('dQdx for electrons in 140 keV at 200 V/cm (DarkSide): '+str(dQdx_DarkSide)+' e/mm')
print('dQdx for MIPs (ICARUS): '+str(dQdx_ICARUS)+' e/mm')
# Out:
# dQdx for electrons in 140 keV at 200 V/cm (DarkSide): 4555.936240771186 e/mm
# dQdx for MIPs (ICARUS): 6234.954661016947 e/mm

# %% [markdown]
# ### ANALYZING CHARGE DENSITIES ###
#
# From these results we find $(\frac{6235}{4556})^2 \approx 1.87$ gives the ratio for comparing the electric fields resulting from the charge densities in the DarkSide and ICARUS cases above. For ionization electrons traveling in a dense medium the velocity is written as $v \approx μ\cdot E$ where μ is the mobility. Since doubling $v$ doubles the impact of Coulomb on ionization cloud spread, if we apply a factor of 2 to the uncertainty we find from analyzing the DarkSide data we will be conservative applying the scaled result to ICARUS.

# %% [markdown]
# ### LOADING DATA ###
#
# The data used for this notebook was digitized as mentioned in the introduction. Below we can see that data plotted.

# %%
#####################################
# VISUALIZING DATA USED IN ANALYSIS #
#####################################

V_per_cm_100_data = np.loadtxt(data_list[0])
V_per_cm_150_data = np.loadtxt(data_list[1])
V_per_cm_200_data = np.loadtxt(data_list[2])

V_per_cm_100_legend = mpatches.Patch(color='yellow', label='100 V/cm: 2.8 kV/cm')
V_per_cm_150_legend = mpatches.Patch(color='mediumturquoise', label='150 V/cm: 2.8 kV/cm')
V_per_cm_200_legend = mpatches.Patch(color='indigo', label='200 V/cm: 2.8 kV/cm')

x = [0, 700]
y = [0, 2.3]

x_axis_V_per_cm_100 = V_per_cm_100_data[:,0]
y_axis_V_per_cm_100 = V_per_cm_100_data[:,1]

x_axis_V_per_cm_150 = V_per_cm_150_data[:,0]
y_axis_V_per_cm_150 = V_per_cm_150_data[:,1]

x_axis_V_per_cm_200 = V_per_cm_200_data[:,0]
y_axis_V_per_cm_200 = V_per_cm_200_data[:,1]

fig, ax = plt.subplots()
ax.scatter(x_axis_V_per_cm_100, y_axis_V_per_cm_100, color='yellow', s=3, marker='.')
ax.scatter(x_axis_V_per_cm_150, y_axis_V_per_cm_150, color='mediumturquoise', s=3, marker='.')
ax.scatter(x_axis_V_per_cm_200, y_axis_V_per_cm_200, color='indigo', s=3, marker='.')
ax.legend(handles=[V_per_cm_200_legend, V_per_cm_150_legend, V_per_cm_100_legend], fontsize=7.5, loc='upper left')

ax.xaxis.set_major_locator(MultipleLocator(100))
ax.xaxis.set_major_formatter('{x:.0f}')
ax.xaxis.set_minor_locator(MultipleLocator(20))

ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.yaxis.set_minor_locator(MultipleLocator(0.05))

ax.set_ylabel('$\sigma^2$ (µs$^2$)')
ax.set_xlabel('$t_{\mathrm{drift}}$$+$t0 (µs)')
# fig.savefig('Diffusion_measurement_at_different_drift_fields')
# Out:
# Text(0.5, 0, '$t_{\\mathrm{drift}}$$+$t0 (µs)')

# %% [markdown]
# ### DATA CLEANING ###
#
# In this next section we look at the individual sets of data after applying the corresponding cleaning variables defined above. These variables clean out points beyond a certain drift time and, in the case of the 150 V/cm data, also clean out a small section in the lower drift times.

# %%
##################################################
# LOOKING AT DATA SETS FOR CLEANING AND ANALYSIS #
##################################################

data = cleaning_func(data_list[0])

x_data = data[0]
y_data = data[1]

plt.scatter(x_axis_V_per_cm_100, y_axis_V_per_cm_100, color='blue', marker='.', s=5, label='Data not being used')
plt.scatter(x_data, y_data, color='red', marker='.', s=3, label='Data being used')
plt.ylabel('$\sigma^2$ (µs$^2$)')
plt.xlabel('$t_{\mathrm{drift}}$$+$t0 (µs)')
plt.legend()
# plt.title('Cleaning 100 V/cm data')
# plt.savefig('Data_cleaning.pdf')

# %% [markdown]
# ### FITTING AND DETERMINING THE QUALITY OF THE MODEL ###
#
# In this next section we apply the fitting function to already cleaned data to get a fit that will be used when calculating the final uncertainty. We can then look at the quality of this fit with the residuals_func function, which is currently being plotted. If the points are randomly distributed around the $y=0$ line then our model is a good fit.

# %%
########################
# PLOTTING FIT TO DATA #
########################

data = cleaning_func(data_list[0])
x = data[0]
y = data[1]

fitting_params = data_fitting(x, y)

plt.scatter(x, y, marker='.', s=8, label='Data')
plt.plot(np.array(x), fitting_params[0]*((np.array(x))+fitting_params[1])**fitting_params[2]+fitting_params[3]*((np.array(x))+fitting_params[1]), color='red', label='Power law plus linear fit to data')
plt.xlabel('$t_{\mathrm{drift}}$$+$t0 (µs)')
plt.ylabel('$\sigma^2$ (µs$^2$)')
plt.title('Fitting 100 V/cm data')
plt.legend()
# plt.savefig('Data_fit.pdf')
# Out:
# [[Model]]
#     Model(data_fit)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 496
#     # variables        = 4
#     chi-square         = 0.15253024
#     reduced chi-square = 3.1002e-04
#     Akaike info crit   = -4003.13630
#     Bayesian info crit = -3986.31000
#     R-squared          = 0.99855922
# [[Variables]]
#     A: -9.40541599 +/- 4.86302578 (51.70%) (init = -0.1)
#     B:  49.9604061 +/- 6.16373639 (12.34%) (init = 0.1)
#     C: -1.04151243 +/- 0.16954862 (16.28%) (init = -0.1)
#     D:  0.00304260 +/- 2.3466e-05 (0.77%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(A, C) = 0.979
#     C(B, D) = -0.978
#     C(B, C) = 0.929
#     C(C, D) = -0.844
#     C(A, B) = 0.836
#     C(A, D) = -0.724

# %%
######################
# PLOTTING RESIDUALS #
######################

plt.scatter(x, residuals_func(x, y, fitting_params[0], fitting_params[1], fitting_params[2], fitting_params[3]), color='red', marker='.', s=5, label='Residuals')
plt.legend()
plt.xlabel('$t_{\mathrm{drift}}$$+$t0 (µs)')
plt.ylabel('Residual')
plt.ylim(-0.1, 0.1)
plt.plot(x, np.zeros(len(x)), color="black")
plt.title('Residual 100 V/cm')
# Out:
# Text(0.5, 1.0, 'Residual 100 V/cm')

# %% [markdown]
# ### CALCULATING UNCERTAINTY ###
#
# This last section uses the last three functions to calculate the relative bias for a range of drift times, 92.3 µs to 136.3 µs, producing plots showing the linear and power law plus linear fits as well as the relative bias as a function of t_A.

# %%
#############################
# RELATIVE BIAS CALCULATION #
#############################

### CALCULATING RB AS A FUNCTION OF t_A FROM t_A, EQUAL TO 92.3 MICROSEC, TO 136.3 MICROSEC ###
run_analysis = RB_per_t_A(t_A+44)

### WITH t_A AND WITHOUT FACTOR OF 2 ###
# 100 V/cm bias: 0.8347966950976045
# 150 V/cm bias: 1.0097045577064816
# 200 V/cm bias: 0.9035914345890026

### WITHOUT t_A OR FACTOR OF 2 ### 
# 100 V/cm bias: 0.6037314332226525
# 150 V/cm bias: 0.7354946835726465
# 200 V/cm bias: 0.6710521009218633

### WITHOUT t_A, POINT_1 OR FACTOR OF 2 ###
# 100 V/cm bias: 0.49637364383859767
# 150 V/cm bias: 0.6054058835317878
# 200 V/cm bias: 0.5583888806441384
# Out:
# [[Model]]
#     Model(data_fit)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 496
#     # variables        = 4
#     chi-square         = 0.15253024
#     reduced chi-square = 3.1002e-04
#     Akaike info crit   = -4003.13630
#     Bayesian info crit = -3986.31000
#     R-squared          = 0.99855922
# [[Variables]]
#     A: -9.40541599 +/- 4.86302578 (51.70%) (init = -0.1)
#     B:  49.9604061 +/- 6.16373639 (12.34%) (init = 0.1)
#     C: -1.04151243 +/- 0.16954862 (16.28%) (init = -0.1)
#     D:  0.00304260 +/- 2.3466e-05 (0.77%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(A, C) = 0.979
#     C(B, D) = -0.978
#     C(B, C) = 0.929
#     C(C, D) = -0.844
#     C(A, B) = 0.836
#     C(A, D) = -0.724
# Variance at t_C: 2.7336999082921682
# Value of linear fit at t_C: 2.7336999082921682
# [[Model]]
#     Model(data_fit)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 62
#     # data points      = 88
#     # variables        = 4
#     chi-square         = 2.6155e-04
#     reduced chi-square = 3.1137e-06
#     Akaike info crit   = -1111.90804
#     Bayesian info crit = -1101.99869
#     R-squared          = 0.99992915
# [[Variables]]
#     A: -6.75886947 +/- 1.04684373 (15.49%) (init = -0.1)
#     B:  59.0072348 +/- 3.17413425 (5.38%) (init = 0.1)
#     C: -1.07163763 +/- 0.05746298 (5.36%) (init = -0.1)
#     D:  0.00147356 +/- 6.4456e-06 (0.44%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(B, D) = -0.980
#     C(A, C) = 0.953
#     C(B, C) = 0.921
#     C(C, D) = -0.838
#     C(A, B) = 0.763
#     C(A, D) = -0.644
# Variance at t_C: 1.3365434428717562
# Value of linear fit at t_C: 1.3365434428717562
# [[Model]]
#     Model(data_fit)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 74
#     # data points      = 124
#     # variables        = 4
#     chi-square         = 2.7216e-04
#     reduced chi-square = 2.2680e-06
#     Akaike info crit   = -1607.64621
#     Bayesian info crit = -1596.36508
#     R-squared          = 0.99980674
# [[Variables]]
#     A: -2.26202602 +/- 0.51196568 (22.63%) (init = -0.1)
#     B:  54.7645323 +/- 4.99143418 (9.11%) (init = 0.1)
#     C: -0.97874640 +/- 0.09013693 (9.21%) (init = -0.1)
#     D:  9.0672e-04 +/- 6.6637e-06 (0.73%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(B, D) = -0.980
#     C(A, C) = 0.947
#     C(B, C) = 0.930
#     C(C, D) = -0.848
#     C(A, B) = 0.764
#     C(A, D) = -0.640
# Variance at t_C: 0.8184813888998079
# Value of linear fit at t_C: 0.8184813888998079
# 100 V/cm bias: 0.8347966950975851
# 150 V/cm bias: 1.0097045577064419
# 200 V/cm bias: 0.9035914345889864
